# %% [markdown]
# # CV AI Agent - Experimentation notebook
#
# This notebook is for exploring feature extraction and scoring on sample CVs.

# %%
from src.cv_parser import extract_text_from_pdf
from src.feature_extraction import parse_cv
from src.scoring import rank_candidates

print('Notebook setup loaded')
